# %% [markdown]
# #This is my Job family prediction model¶

# %%
import os
import boto3
import re
import copy
import time
from time import gmtime, strftime
from sagemaker import get_execution_role

role = get_execution_role()

region = boto3.Session().region_name

bucket='testtestbill' # Replace with your s3 bucket name
prefix = 'sagemaker/jobfamily' # Used as part of the path in the bucket where you store data
bucket_path = 'https://s3-{}.amazonaws.com/{}'.format(region,bucket) # The URL to access the bucket

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Access data from the lake and filter down to target pop#

# %%
df = pd.read_csv('jfoutput.csv')

# %%
df['category_id'] = df['JF'].factorize()[0]

# %%
from io import StringIO
category_id_df = df[['JF', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'JF']].values)

# %% [markdown]
# #train the model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(df.Position).toarray()
labels = df.category_id
features.shape
# Out:
# (53573, 3890)

# %%
from sklearn.feature_selection import chi2
import numpy as np

N = 2
for JF, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(JF))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'AD_Administration':
#   . Most correlated unigrams:
#        . assistant
#        . administrator
#   . Most correlated bigrams:
#        . executive assistant
#        . vacation worker
# # 'AS_Asset Strategy':
#   . Most correlated unigrams:
#        . strategic
#        . asset
#   . Most correlated bigrams:
#        . practice lead
#        . manager maintenance
# # 'AU_Governance Audit & Assurance':
#   . Most correlated unigrams:
#        . internal
#        . audit
#   . Most correlated bigrams:
#        . audit assurance
#        . internal audit
# # 'BA_Business Analysis':
#   . Most correlated unigrams:
#        . analysis
#        . ba
#   . Most correlated bigrams:
#        . business analysis
#        . advisor ba
# # 'BD_Business Development':
#   . Most correlated unigrams:
#        . investor
#        . ventures
#   . Most correlated bigrams:
#        . gm business
#        . business development
# # 'BI_Business Improvement':
#   . Most correlated unigrams:
#        . black
#        . improvement
#   . Most correlated bigrams:
#        . black belt
#        . business improvement
# # 'BP_Business Strategy Planning':
#   . Most correlated unigrams:
#        . bus
#        . architecture
#   . Most correlated bigrams:
#        . process consulting
#        . business process
# # 'BS_Business Strategy':
#   . Most correlated unigrams:
#        . jvs
#        . partnerships
#   . Most correlated bigrams:
#        . gm commercial
#        . commercial strategy
# # 'CH_Chemistry':
#   . Most correlated unigrams:
#        . laboratory
#        . chemist
#   . Most correlated bigrams:
#        . laboratory analyst
#        . metallurgy technician
# # 'CM_Category Management':
#   . Most correlated unigrams:
#        . supplier
#        . sourcing
#   . Most correlated bigrams:
#        . specialist local
#        . analyst sourcing
# # 'CM_Change Management':
#   . Most correlated unigrams:
#        . agent
#        . change
#   . Most correlated bigrams:
#        . senior advisor
#        . change management
# # 'CM_Commissioning Management':
#   . Most correlated unigrams:
#        . signals
#        . comms
#   . Most correlated bigrams:
#        . operator maintainer
#        . superintendent projects
# # 'CN_Construction Management':
#   . Most correlated unigrams:
#        . area
#        . construction
#   . Most correlated bigrams:
#        . construction coordinator
#        . superintendent construction
# # 'CP_Compliance':
#   . Most correlated unigrams:
#        . diligence
#        . investigations
#   . Most correlated bigrams:
#        . manager compliance
#        . diligence analyst
# # 'CR_Controlling & Reporting':
#   . Most correlated unigrams:
#        . accountant
#        . controllership
#   . Most correlated bigrams:
#        . closing reporting
#        . advisor controllership
# # 'CS_Communities & Social Performance':
#   . Most correlated unigrams:
#        . indigenous
#        . community
#   . Most correlated bigrams:
#        . community relations
#        . cultural heritage
# # 'CS_Cyber Security':
#   . Most correlated unigrams:
#        . advisory
#        . cyber
#   . Most correlated bigrams:
#        . risk advisory
#        . advisor cyber
# # 'CS_Secretariat':
#   . Most correlated unigrams:
#        . secretariat
#        . company
#   . Most correlated bigrams:
#        . assistant company
#        . company secretary
# # 'CV_Civil':
#   . Most correlated unigrams:
#        . smp
#        . civil
#   . Most correlated bigrams:
#        . analyst engineer
#        . engineer civil
# # 'Contractors':
#   . Most correlated unigrams:
#        . contractor
#        . cat
#   . Most correlated bigrams:
#        . contractor operator
#        . cat contractor
# # 'DA_Data & Analytics':
#   . Most correlated unigrams:
#        . data
#        . science
#   . Most correlated bigrams:
#        . data science
#        . specialist data
# # 'DB_Surface Drill & Blast Operations':
#   . Most correlated unigrams:
#        . drill
#        . blast
#   . Most correlated bigrams:
#        . engineer drill
#        . drill blast
# # 'DB_UG Drill & Blast Operations':
#   . Most correlated unigrams:
#        . blast
#        . mining
#   . Most correlated bigrams:
#        . graduate mining
#        . engineer mining
# # 'DE_Discipline Engineering':
#   . Most correlated unigrams:
#        . graduate
#        . engineer
#   . Most correlated bigrams:
#        . engineer mechanical
#        . engineer electrical
# # 'DM_Data Management':
#   . Most correlated unigrams:
#        . data
#        . geoscientific
#   . Most correlated bigrams:
#        . data specialist
#        . geoscientific data
# # 'EA_External Affairs':
#   . Most correlated unigrams:
#        . affairs
#        . external
#   . Most correlated bigrams:
#        . corporate relations
#        . external affairs
# # 'EE_Environmental':
#   . Most correlated unigrams:
#        . tailings
#        . dams
#   . Most correlated bigrams:
#        . tailings dams
#        . advisor tailings
# # 'EL_Electrical':
#   . Most correlated unigrams:
#        . engineer
#        . electrical
#   . Most correlated bigrams:
#        . electrical engineer
#        . engineer electrical
# # 'EM_Engineering Management':
#   . Most correlated unigrams:
#        . manager
#        . project
#   . Most correlated bigrams:
#        . project engineer
#        . project manager
# # 'ER_Employee Relations':
#   . Most correlated unigrams:
#        . employee
#        . er
#   . Most correlated bigrams:
#        . advisor industrial
#        . employee relation
# # 'EV_Environment':
#   . Most correlated unigrams:
#        . environmental
#        . environment
#   . Most correlated bigrams:
#        . specialist environment
#        . advisor environment
# # 'EV_Evaluation':
#   . Most correlated unigrams:
#        . estimation
#        . geologist
#   . Most correlated bigrams:
#        . senior geologist
#        . evaluation metallurgist
# # 'EX_Exploration':
#   . Most correlated unigrams:
#        . exploration
#        . geoscientist
#   . Most correlated bigrams:
#        . principal geoscientist
#        . project geoscientist
# # 'FP_Facilities & Property':
#   . Most correlated unigrams:
#        . concierge
#        . emergency
#   . Most correlated bigrams:
#        . officer emergency
#        . emergency services
# # 'FP_Finance Business Partnering':
#   . Most correlated unigrams:
#        . fbp
#        . finance
#   . Most correlated bigrams:
#        . advisor finance
#        . finance business
# # 'GC_IS&T Governance & Compliance':
#   . Most correlated unigrams:
#        . portfolio
#        . governance
#   . Most correlated bigrams:
#        . cyber risk
#        . portfolio management
# # 'GE_Geotechnical Engineering':
#   . Most correlated unigrams:
#        . geotech
#        . geotechnical
#   . Most correlated bigrams:
#        . technician geotechnical
#        . engineer geotechnical
# # 'GM_General Management':
#   . Most correlated unigrams:
#        . executive
#        . coe
#   . Most correlated bigrams:
#        . chief executive
#        . mining executive
# # 'HA_HR Advisory':
#   . Most correlated unigrams:
#        . adviser
#        . hr
#   . Most correlated bigrams:
#        . hr advisor
#        . hr adviser
# # 'HE_Health':
#   . Most correlated unigrams:
#        . occupational
#        . nurse
#   . Most correlated bigrams:
#        . advisor injury
#        . occupational health
# # 'HG_HSE Generalist':
#   . Most correlated unigrams:
#        . health
#        . hse
#   . Most correlated bigrams:
#        . advisor health
#        . health safety
# # 'HM_HSE System, Assurance & Information':
#   . Most correlated unigrams:
#        . hse
#        . sustainability
#   . Most correlated bigrams:
#        . advisor hse
#        . systems advisor
# # 'HO_HR Business Partnering':
#   . Most correlated unigrams:
#        . hr
#        . hrbp
#   . Most correlated bigrams:
#        . human resources
#        . hrbp rtio
# # 'IC_Instrumentation & Control':
#   . Most correlated unigrams:
#        . computer
#        . mechatronics
#   . Most correlated bigrams:
#        . engineer control
#        . engineer signals
# # 'IO_Infrastructure Operations':
#   . Most correlated unigrams:
#        . network
#        . locomotive
#   . Most correlated bigrams:
#        . network locomotive
#        . locomotive driver
# # 'IP_Infrastructure Planning & Scheduling':
#   . Most correlated unigrams:
#        . stockpile
#        . inload
#   . Most correlated bigrams:
#        . metal mgmt
#        . scheduler stockpile
# # 'IR_Investor Relations':
#   . Most correlated unigrams:
#        . relations
#        . investor
#   . Most correlated bigrams:
#        . senior analyst
#        . investor relations
# # 'LD_Learning & Development':
#   . Most correlated unigrams:
#        . trainer
#        . training
#   . Most correlated bigrams:
#        . training officer
#        . officer training
# # 'LE_Legal':
#   . Most correlated unigrams:
#        . corporate
#        . counsel
#   . Most correlated bigrams:
#        . chief counsel
#        . corporate counsel
# # 'LN_Land':
#   . Most correlated unigrams:
#        . permitting
#        . approvals
#   . Most correlated bigrams:
#        . land mineral
#        . mineral rights
# # 'MC_Media & Communications':
#   . Most correlated unigrams:
#        . communications
#        . translator
#   . Most correlated bigrams:
#        . advisor media
#        . advisor communications
# # 'ME_Mechanical':
#   . Most correlated unigrams:
#        . graduate
#        . engineer
#   . Most correlated bigrams:
#        . mechanical engineer
#        . engineer mechanical
# # 'MG_Mine Geology':
#   . Most correlated unigrams:
#        . geology
#        . geologist
#   . Most correlated bigrams:
#        . geologist underground
#        . senior geologist
# # 'MI_Market & Business Intelligence':
#   . Most correlated unigrams:
#        . analysis
#        . market
#   . Most correlated bigrams:
#        . analyst market
#        . market analysis
# # 'MI_Mining':
#   . Most correlated unigrams:
#        . engineer
#        . mining
#   . Most correlated bigrams:
#        . mining engineer
#        . engineer mining
# # 'MK_Marketing':
#   . Most correlated unigrams:
#        . pricing
#        . marketing
#   . Most correlated bigrams:
#        . marketing services
#        . technical marketing
# # 'MO_Maintenance Operations':
#   . Most correlated unigrams:
#        . mechanical
#        . maintainer
#   . Most correlated bigrams:
#        . operator mechanical
#        . maintainer operator
# # 'MO_Surface Mine Operations':
#   . Most correlated unigrams:
#        . mobile
#        . operator
#   . Most correlated bigrams:
#        . operator hme
#        . operator mobile
# # 'MO_UG Mine Operations':
#   . Most correlated unigrams:
#        . slickline
#        . miner
#   . Most correlated bigrams:
#        . operator ug
#        . ug logistics
# # 'Not assigned':
#   . Most correlated unigrams:
#        . contractors
#        . 99999999
#   . Most correlated bigrams:
#        . reliability engineer
#        . graduate reliability
# # 'OC_Operational & Closure Readiness':
#   . Most correlated unigrams:
#        . operational
#        . readiness
#   . Most correlated bigrams:
#        . business readiness
#        . ces business
# # 'OE_Organisational Effectiveness':
#   . Most correlated unigrams:
#        . effectiveness
#        . org
#   . Most correlated bigrams:
#        . advisor org
#        . org effectiveness
# # 'OP_Operations':
#   . Most correlated unigrams:
#        . brazil
#        . md
#   . Most correlated bigrams:
#        . chief operating
#        . operating officer
# # 'OS_Operations & Support':
#   . Most correlated unigrams:
#        . systems
#        . applications
#   . Most correlated bigrams:
#        . analyst site
#        . site support
# # 'OT_Operational Technology':
#   . Most correlated unigrams:
#        . expert
#        . automation
#   . Most correlated bigrams:
#        . draftsman technician
#        . automation engineer
# # 'PC_Process Control':
#   . Most correlated unigrams:
#        . computer
#        . work
#   . Most correlated bigrams:
#        . advanced process
#        . civil technician
# # 'PC_Project Controls':
#   . Most correlated unigrams:
#        . controls
#        . cost
#   . Most correlated bigrams:
#        . advisor cost
#        . project controls
# # 'PE_Process Engineering':
#   . Most correlated unigrams:
#        . engineer
#        . metallurgist
#   . Most correlated bigrams:
#        . engineer process
#        . process engineer
# # 'PE_Project':
#   . Most correlated unigrams:
#        . manager
#        . project
#   . Most correlated bigrams:
#        . sector leader
#        . project manager
# # 'PM_Project Management':
#   . Most correlated unigrams:
#        . project
#        . studies
#   . Most correlated bigrams:
#        . gm project
#        . principal studies
# # 'PO_Processing Operations':
#   . Most correlated unigrams:
#        . controller
#        . process
#   . Most correlated bigrams:
#        . operator plant
#        . process technician
# # 'PP_Project Procurement':
#   . Most correlated unigrams:
#        . procurement
#        . contracts
#   . Most correlated bigrams:
#        . procurement contracts
#        . advisor contracts
# # 'PS_Asset Planning & Scheduling':
#   . Most correlated unigrams:
#        . scheduler
#        . planner
#   . Most correlated bigrams:
#        . maintenance planner
#        . planner maintenance
# # 'PS_Proc. Planning & Scheduling':
#   . Most correlated unigrams:
#        . blue
#        . scheduler
#   . Most correlated bigrams:
#        . operations scheduler
#        . production advisor
# # 'PS_Procurement Services':
#   . Most correlated unigrams:
#        . p2p
#        . buy
#   . Most correlated bigrams:
#        . analyst ap
#        . analyst buy
# # 'PS_Surface Mine Planning & Scheduling':
#   . Most correlated unigrams:
#        . scheduling
#        . mining
#   . Most correlated bigrams:
#        . mining engineer
#        . engineer scheduling
# # 'PS_UG Mine Planning & Scheduling':
#   . Most correlated unigrams:
#        . design
#        . caving
#   . Most correlated bigrams:
#        . advisor ug
#        . mining centre
# # 'PY_Payroll':
#   . Most correlated unigrams:
#        . edm
#        . payroll
#   . Most correlated bigrams:
#        . officer payroll
#        . adviser payroll
# # 'RD_Research & Development':
#   . Most correlated unigrams:
#        . research
#        . scientist
#   . Most correlated bigrams:
#        . specialist metallurgy
#        . research scientist
# # 'RE_Reliability Engineering':
#   . Most correlated unigrams:
#        . fiabiliste
#        . reliability
#   . Most correlated bigrams:
#        . reliability mem
#        . engineer reliability
# # 'RE_Resourcing':
#   . Most correlated unigrams:
#        . offers
#        . recruitment
#   . Most correlated bigrams:
#        . checks offers
#        . recruitment partner
# # 'RI_Risk':
#   . Most correlated unigrams:
#        . credit
#        . risk
#   . Most correlated bigrams:
#        . advisor risk
#        . risk business
# # 'RM_AM Risk Mgt & Assurance':
#   . Most correlated unigrams:
#        . assets
#        . integrity
#   . Most correlated bigrams:
#        . asset risk
#        . asset integrity
# # 'RM_Proc. Tech Risk Mgt & Assurance':
#   . Most correlated unigrams:
#        . assurance
#        . quality
#   . Most correlated bigrams:
#        . principal advisor
#        . quality assurance
# # 'RW_Reward':
#   . Most correlated unigrams:
#        . benefits
#        . mobility
#   . Most correlated bigrams:
#        . adviser benefits
#        . global mobility
# # 'SA_Process Safety':
#   . Most correlated unigrams:
#        . champion
#        . safety
#   . Most correlated bigrams:
#        . safety champion
#        . process safety
# # 'SA_Safety':
#   . Most correlated unigrams:
#        . hse
#        . safety
#   . Most correlated bigrams:
#        . officer safety
#        . advisor safety
# # 'SA_Sales':
#   . Most correlated unigrams:
#        . sales
#        . customer
#   . Most correlated bigrams:
#        . service representative
#        . customer service
# # 'SD_Solution Development':
#   . Most correlated unigrams:
#        . report
#        . enablement
#   . Most correlated bigrams:
#        . project enablement
#        . business controls
# # 'SE_Security':
#   . Most correlated unigrams:
#        . security
#        . resilience
#   . Most correlated bigrams:
#        . business resilience
#        . specialist cr
# # 'SM_Business Service Management':
#   . Most correlated unigrams:
#        . writer
#        . document
#   . Most correlated bigrams:
#        . document control
#        . data controller
# # 'SM_Sales & Marketing':
#   . Most correlated unigrams:
#        . region
#        . sales
#   . Most correlated bigrams:
#        . manager sales
#        . sales marketing
# # 'SM_Study Management':
#   . Most correlated unigrams:
#        . studies
#        . study
#   . Most correlated bigrams:
#        . principal technology
#        . study lead
# # 'SP_Strategic Business Partnerships':
#   . Most correlated unigrams:
#        . bp
#        . gm
#   . Most correlated bigrams:
#        . manager procurement
#        . senior business
# # 'SU_Surface Surveying':
#   . Most correlated unigrams:
#        . survey
#        . surveyor
#   . Most correlated bigrams:
#        . senior surveyor
#        . specialist surveyor
# # 'SU_UG Surveying':
#   . Most correlated unigrams:
#        . survey
#        . surveyor
#   . Most correlated bigrams:
#        . senior surveyor
#        . technician surveyor
# # 'TA_Talent':
#   . Most correlated unigrams:
#        . graduates
#        . talent
#   . Most correlated bigrams:
#        . manager performance
#        . adviser talent
# # 'TL_Transportation & Logistics':
#   . Most correlated unigrams:
#        . locomotive
#        . supply
#   . Most correlated bigrams:
#        . locomotive driver
#        . officer supply
# # 'TM_Tailings Management':
#   . Most correlated unigrams:
#        . dams
#        . tailings
#   . Most correlated bigrams:
#        . tailings dams
#        . engineer tailings
# # 'TR_Treasury':
#   . Most correlated unigrams:
#        . treasury
#        . structured
#   . Most correlated bigrams:
#        . global markets
#        . corporate finance
# # 'TX_Tax':
#   . Most correlated unigrams:
#        . indirect
#        . tax
#   . Most correlated bigrams:
#        . advisor tax
#        . tax risk
# # 'VE_Ventilation':
#   . Most correlated unigrams:
#        . mts
#        . ventilation
#   . Most correlated bigrams:
#        . engineer mts
#        . engineer ventilation
# # 'WA_Water':
#   . Most correlated unigrams:
#        . hydrologist
#        . hydrogeologist
#   . Most correlated bigrams:
#        . field hydrogeologist
#        . senior hydrogeologist
# # 'WP_Workforce Planning & Analytics':
#   . Most correlated unigrams:
#        . people
#        . workforce
#   . Most correlated bigrams:
#        . workforce planning
#        . people analytics

# %% [markdown]
# See here for the test train split stuff
#
# here is a link for the estimator: https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/scikit_learn_iris/Scikit-learn%20Estimator%20Example%20With%20Batch%20Transform.ipynb

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(df['Position'], df['JF'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform(["HRBP"])))
# Out:
# ['HO_HR Business Partnering']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_score


models = [
    LinearSVC()
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC    0.720458
# Name: accuracy, dtype: float64

# %%
from sklearn.model_selection import train_test_split

model = LinearSVC()

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
model.fit(features, labels)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
from sklearn.feature_selection import chi2

N = 2
for JF, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(JF))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# # 'AD_Administration':
#   . Top unigrams:
#        . secretary
#        . receptionist
#   . Top bigrams:
#        . vacation worker
#        . training support
# # 'AS_Asset Strategy':
#   . Top unigrams:
#        . sme
#        . growth
#   . Top bigrams:
#        . chief adv
#        . practice lead
# # 'AU_Governance Audit & Assurance':
#   . Top unigrams:
#        . audit
#        . internal
#   . Top bigrams:
#        . audit assurance
#        . internal audit
# # 'BA_Business Analysis':
#   . Top unigrams:
#        . ba
#        . economics
#   . Top bigrams:
#        . business analysis
#        . business evaluation
# # 'BD_Business Development':
#   . Top unigrams:
#        . ventures
#        . bd
#   . Top bigrams:
#        . business development
#        . gm business
# # 'BI_Business Improvement':
#   . Top unigrams:
#        . lean
#        . client
#   . Top bigrams:
#        . superintendent business
#        . readiness lead
# # 'BP_Business Strategy Planning':
#   . Top unigrams:
#        . ot
#        . bus
#   . Top bigrams:
#        . business process
#        . mgmt systems
# # 'BS_Business Strategy':
#   . Top unigrams:
#        . partnerships
#        . jvs
#   . Top bigrams:
#        . commercial strategy
#        . development officer
# # 'CH_Chemistry':
#   . Top unigrams:
#        . metallurgy
#        . chemist
#   . Top bigrams:
#        . laboratory services
#        . officer laboratory
# # 'CM_Category Management':
#   . Top unigrams:
#        . supplier
#        . mro
#   . Top bigrams:
#        . specialist local
#        . technology outsourcing
# # 'CM_Change Management':
#   . Top unigrams:
#        . agent
#        . lead
#   . Top bigrams:
#        . change management
#        . senior advisor
# # 'CM_Commissioning Management':
#   . Top unigrams:
#        . comms
#        . signals
#   . Top bigrams:
#        . superintendent projects
#        . data entry
# # 'CN_Construction Management':
#   . Top unigrams:
#        . construction
#        . superintendant
#   . Top bigrams:
#        . construction coordinator
#        . manager area
# # 'CP_Compliance':
#   . Top unigrams:
#        . investigations
#        . diligence
#   . Top bigrams:
#        . manager compliance
#        . diligence analyst
# # 'CR_Controlling & Reporting':
#   . Top unigrams:
#        . controllership
#        . accounting
#   . Top bigrams:
#        . finance assistant
#        . sites controller
# # 'CS_Communities & Social Performance':
#   . Top unigrams:
#        . community
#        . csp
#   . Top bigrams:
#        . indigenous support
#        . management technician
# # 'CS_Cyber Security':
#   . Top unigrams:
#        . response
#        . cyber
#   . Top bigrams:
#        . technical assurance
#        . advisor cyber
# # 'CS_Secretariat':
#   . Top unigrams:
#        . secretariat
#        . company
#   . Top bigrams:
#        . company secretary
#        . general counsel
# # 'CV_Civil':
#   . Top unigrams:
#        . residue
#        . smp
#   . Top bigrams:
#        . advisor civil
#        . analyst engineer
# # 'Contractors':
#   . Top unigrams:
#        . workpac
#        . cat
#   . Top bigrams:
#        . cat contractor
#        . contract operator
# # 'DA_Data & Analytics':
#   . Top unigrams:
#        . decision
#        . pace
#   . Top bigrams:
#        . engineer analytics
#        . data engineer
# # 'DB_Surface Drill & Blast Operations':
#   . Top unigrams:
#        . blast
#        . quarry
#   . Top bigrams:
#        . supervisor blasting
#        . supervisor drilling
# # 'DB_UG Drill & Blast Operations':
#   . Top unigrams:
#        . mts
#        . ug
#   . Top bigrams:
#        . planner mts
#        . graduate mining
# # 'DE_Discipline Engineering':
#   . Top unigrams:
#        . refection
#        . pdm
#   . Top bigrams:
#        . maintenance mem
#        . stagiaire ingenieur
# # 'DM_Data Management':
#   . Top unigrams:
#        . im
#        . gis
#   . Top bigrams:
#        . geoscientific data
#        . reserves data
# # 'EA_External Affairs':
#   . Top unigrams:
#        . country
#        . government
#   . Top bigrams:
#        . corporate relations
#        . gm communities
# # 'EE_Environmental':
#   . Top unigrams:
#        . geochemistry
#        . land
#   . Top bigrams:
#        . advisor tailings
#        . environmental engineer
# # 'EL_Electrical':
#   . Top unigrams:
#        . ips
#        . electrical
#   . Top bigrams:
#        . student electrical
#        . automation advisor
# # 'EM_Engineering Management':
#   . Top unigrams:
#        . al
#        . rda
#   . Top bigrams:
#        . lead power
#        . data systems
# # 'ER_Employee Relations':
#   . Top unigrams:
#        . er
#        . relations
#   . Top bigrams:
#        . employee relation
#        . contracts coordinator
# # 'EV_Environment':
#   . Top unigrams:
#        . environment
#        . biodiversity
#   . Top bigrams:
#        . advisor water
#        . environment advisor
# # 'EV_Evaluation':
#   . Top unigrams:
#        . estimation
#        . evaluation
#   . Top bigrams:
#        . geologist resource
#        . project geologist
# # 'EX_Exploration':
#   . Top unigrams:
#        . exploration
#        . driller
#   . Top bigrams:
#        . field assistant
#        . technical assistant
# # 'FP_Facilities & Property':
#   . Top unigrams:
#        . guard
#        . driver
#   . Top bigrams:
#        . site control
#        . inspector equipment
# # 'FP_Finance Business Partnering':
#   . Top unigrams:
#        . bpo
#        . fbp
#   . Top bigrams:
#        . finance business
#        . chief financial
# # 'GC_IS&T Governance & Compliance':
#   . Top unigrams:
#        . governance
#        . assurance
#   . Top bigrams:
#        . portfolio management
#        . project management
# # 'GE_Geotechnical Engineering':
#   . Top unigrams:
#        . geotechnical
#        . geotech
#   . Top bigrams:
#        . technician data
#        . data processing
# # 'GM_General Management':
#   . Top unigrams:
#        . executive
#        . chief
#   . Top bigrams:
#        . mining executive
#        . chief executive
# # 'HA_HR Advisory':
#   . Top unigrams:
#        . hr
#        . nzas
#   . Top bigrams:
#        . service optimisation
#        . advisor employee
# # 'HE_Health':
#   . Top unigrams:
#        . hygiene
#        . ih
#   . Top bigrams:
#        . advisor injury
#        . advisor hygiene
# # 'HG_HSE Generalist':
#   . Top unigrams:
#        . hsec
#        . hse
#   . Top bigrams:
#        . coordinator safety
#        . health safety
# # 'HM_HSE System, Assurance & Information':
#   . Top unigrams:
#        . sustainability
#        . auditor
#   . Top bigrams:
#        . systems advisor
#        . management systems
# # 'HO_HR Business Partnering':
#   . Top unigrams:
#        . hrbp
#        . hr
#   . Top bigrams:
#        . hr business
#        . president human
# # 'IC_Instrumentation & Control':
#   . Top unigrams:
#        . mechatronics
#        . testing
#   . Top bigrams:
#        . engineer signals
#        . systems software
# # 'IO_Infrastructure Operations':
#   . Top unigrams:
#        . pilot
#        . mainline
#   . Top bigrams:
#        . utilities operations
#        . crane driver
# # 'IP_Infrastructure Planning & Scheduling':
#   . Top unigrams:
#        . inload
#        . scheduling
#   . Top bigrams:
#        . scheduler stockpile
#        . superintendent port
# # 'IR_Investor Relations':
#   . Top unigrams:
#        . investor
#        . executive
#   . Top bigrams:
#        . investor relations
#        . general manager
# # 'LD_Learning & Development':
#   . Top unigrams:
#        . training
#        . lms
#   . Top bigrams:
#        . trainer hse
#        . supervisor training
# # 'LE_Legal':
#   . Top unigrams:
#        . counsel
#        . patent
#   . Top bigrams:
#        . corporate counsel
#        . chief counsel
# # 'LN_Land':
#   . Top unigrams:
#        . approvals
#        . permitting
#   . Top bigrams:
#        . coordinator permitting
#        . officer tenure
# # 'MC_Media & Communications':
#   . Top unigrams:
#        . translator
#        . media
#   . Top bigrams:
#        . manager communications
#        . advisor brand
# # 'ME_Mechanical':
#   . Top unigrams:
#        . pump
#        . wagons
#   . Top bigrams:
#        . area mech
#        . engineer training
# # 'MG_Mine Geology':
#   . Top unigrams:
#        . geology
#        . geophysicist
#   . Top bigrams:
#        . assistant contractor
#        . geologist underground
# # 'MI_Market & Business Intelligence':
#   . Top unigrams:
#        . market
#        . high
#   . Top bigrams:
#        . market analysis
#        . advisor op
# # 'MI_Mining':
#   . Top unigrams:
#        . mts
#        . ventilation
#   . Top bigrams:
#        . supt technical
#        . survey technician
# # 'MK_Marketing':
#   . Top unigrams:
#        . marketing
#        . pricing
#   . Top bigrams:
#        . manager iron
#        . superintendent technical
# # 'MO_Maintenance Operations':
#   . Top unigrams:
#        . mechanic
#        . maintainer
#   . Top bigrams:
#        . tailings maintenance
#        . room field
# # 'MO_Surface Mine Operations':
#   . Top unigrams:
#        . bioc
#        . haul
#   . Top bigrams:
#        . assistant drill
#        . leader open
# # 'MO_UG Mine Operations':
#   . Top unigrams:
#        . slickline
#        . deck
#   . Top bigrams:
#        . operator crusher
#        . operator hoist
# # 'Not assigned':
#   . Top unigrams:
#        . 99999999
#        . cl
#   . Top bigrams:
#        . graduate reliability
#        . student electrical
# # 'OC_Operational & Closure Readiness':
#   . Top unigrams:
#        . readiness
#        . autohaul
#   . Top bigrams:
#        . advisor ops
#        . manager operational
# # 'OE_Organisational Effectiveness':
#   . Top unigrams:
#        . org
#        . culture
#   . Top bigrams:
#        . org effectiveness
#        . advisor org
# # 'OP_Operations':
#   . Top unigrams:
#        . md
#        . brazil
#   . Top bigrams:
#        . pacific operations
#        . chief executive
# # 'OS_Operations & Support':
#   . Top unigrams:
#        . network
#        . rtx
#   . Top bigrams:
#        . site support
#        . service desk
# # 'OT_Operational Technology':
#   . Top unigrams:
#        . alpsys
#        . expert
#   . Top bigrams:
#        . delivery project
#        . mining automation
# # 'PC_Process Control':
#   . Top unigrams:
#        . group
#        . vdc
#   . Top bigrams:
#        . civil technician
#        . specialist automation
# # 'PC_Project Controls':
#   . Top unigrams:
#        . cost
#        . programs
#   . Top bigrams:
#        . project controller
#        . project controls
# # 'PE_Process Engineering':
#   . Top unigrams:
#        . simulation
#        . metallurgist
#   . Top bigrams:
#        . development engineer
#        . manager tech
# # 'PE_Project':
#   . Top unigrams:
#        . cmp
#        . projets
#   . Top bigrams:
#        . coordinator construction
#        . data systems
# # 'PM_Project Management':
#   . Top unigrams:
#        . gtp
#        . non
#   . Top bigrams:
#        . gm project
#        . principal studies
# # 'PO_Processing Operations':
#   . Top unigrams:
#        . controllers
#        . aluminum
#   . Top bigrams:
#        . driver mobile
#        . operator plant
# # 'PP_Project Procurement':
#   . Top unigrams:
#        . contracts
#        . proj
#   . Top bigrams:
#        . procurement contracts
#        . manager contracts
# # 'PS_Asset Planning & Scheduling':
#   . Top unigrams:
#        . planner
#        . scheduler
#   . Top bigrams:
#        . master data
#        . coordinator shutdown
# # 'PS_Proc. Planning & Scheduling':
#   . Top unigrams:
#        . metal
#        . blue
#   . Top bigrams:
#        . operations scheduler
#        . production advisor
# # 'PS_Procurement Services':
#   . Top unigrams:
#        . buy
#        . p2p
#   . Top bigrams:
#        . mining material
#        . officer ap
# # 'PS_Surface Mine Planning & Scheduling':
#   . Top unigrams:
#        . mining
#        . practice
#   . Top bigrams:
#        . engineer scheduling
#        . engineer production
# # 'PS_UG Mine Planning & Scheduling':
#   . Top unigrams:
#        . mrp
#        . caving
#   . Top bigrams:
#        . mining centre
#        . scheduling engineer
# # 'PY_Payroll':
#   . Top unigrams:
#        . payroll
#        . edm
#   . Top bigrams:
#        . contact centre
#        . adviser payroll
# # 'RD_Research & Development':
#   . Top unigrams:
#        . research
#        . scientist
#   . Top bigrams:
#        . development specialist
#        . specialist metallurgy
# # 'RE_Reliability Engineering':
#   . Top unigrams:
#        . reliability
#        . fiabiliste
#   . Top bigrams:
#        . asset health
#        . process optimisation
# # 'RE_Resourcing':
#   . Top unigrams:
#        . recruitment
#        . offers
#   . Top bigrams:
#        . strategic sourcing
#        . specialist strategic
# # 'RI_Risk':
#   . Top unigrams:
#        . risk
#        . credit
#   . Top bigrams:
#        . integrated assurance
#        . risk business
# # 'RM_AM Risk Mgt & Assurance':
#   . Top unigrams:
#        . integrity
#        . assets
#   . Top bigrams:
#        . asset risk
#        . classified plant
# # 'RM_Proc. Tech Risk Mgt & Assurance':
#   . Top unigrams:
#        . casting
#        . quality
#   . Top bigrams:
#        . quality assurance
#        . principal advisor
# # 'RW_Reward':
#   . Top unigrams:
#        . remuneration
#        . benefits
#   . Top bigrams:
#        . global mobility
#        . executive reward
# # 'SA_Process Safety':
#   . Top unigrams:
#        . safety
#        . ordinator
#   . Top bigrams:
#        . process safety
#        . advisor process
# # 'SA_Safety':
#   . Top unigrams:
#        . safety
#        . crm
#   . Top bigrams:
#        . manager safety
#        . officer safety
# # 'SA_Sales':
#   . Top unigrams:
#        . sales
#        . products
#   . Top bigrams:
#        . customer service
#        . metal management
# # 'SD_Solution Development':
#   . Top unigrams:
#        . solutions
#        . report
#   . Top bigrams:
#        . business controls
#        . quality services
# # 'SE_Security':
#   . Top unigrams:
#        . resilience
#        . cr
#   . Top bigrams:
#        . specialist cr
#        . business resilience
# # 'SM_Business Service Management':
#   . Top unigrams:
#        . writer
#        . cmc
#   . Top bigrams:
#        . data controller
#        . document control
# # 'SM_Sales & Marketing':
#   . Top unigrams:
#        . stewardship
#        . region
#   . Top bigrams:
#        . manager aluminium
#        . portfolio metal
# # 'SM_Study Management':
#   . Top unigrams:
#        . new
#        . gm
#   . Top bigrams:
#        . study lead
#        . principal technology
# # 'SP_Strategic Business Partnerships':
#   . Top unigrams:
#        . svcs
#        . bp
#   . Top bigrams:
#        . manager technology
#        . manager logistics
# # 'SU_Surface Surveying':
#   . Top unigrams:
#        . surveyor
#        . survey
#   . Top bigrams:
#        . blast survey
#        . specialist surveyor
# # 'SU_UG Surveying':
#   . Top unigrams:
#        . survey
#        . surveyor
#   . Top bigrams:
#        . technician surveyor
#        . senior surveyor
# # 'TA_Talent':
#   . Top unigrams:
#        . talent
#        . graduates
#   . Top bigrams:
#        . adviser talent
#        . manager performance
# # 'TL_Transportation & Logistics':
#   . Top unigrams:
#        . supply
#        . freight
#   . Top bigrams:
#        . regional operations
#        . operator toolstore
# # 'TM_Tailings Management':
#   . Top unigrams:
#        . dams
#        . tailings
#   . Top bigrams:
#        . tailings dams
#        . engineer tailings
# # 'TR_Treasury':
#   . Top unigrams:
#        . structured
#        . cash
#   . Top bigrams:
#        . corporate finance
#        . global markets
# # 'TX_Tax':
#   . Top unigrams:
#        . tax
#        . taxation
#   . Top bigrams:
#        . transfer pricing
#        . tax risk
# # 'VE_Ventilation':
#   . Top unigrams:
#        . ventilation
#        . mts
#   . Top bigrams:
#        . engineer ventilation
#        . engineer mts
# # 'WA_Water':
#   . Top unigrams:
#        . hydrogeologist
#        . hydrogeology
#   . Top bigrams:
#        . water monitoring
#        . water management
# # 'WP_Workforce Planning & Analytics':
#   . Top unigrams:
#        . workforce
#        . partnership
#   . Top bigrams:
#        . people analytics
#        . officer edm

# %%
import pickle

# %%
# save the model to disk
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))
